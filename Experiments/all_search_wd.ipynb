# %%
import os
os.environ['TRANSFORMERS_CACHE'] = '/mnt/software/'
import sys
import gc
# assuming data, models, engine in flicc directory:
flicc_path = os.path.join(os.path.dirname(os.getcwd()), '')
sys.path.append(flicc_path)
import torch
from data import ClimateDataset
from models import ClassificationModel
from engine import Engine

# import warnings
# warnings.filterwarnings("ignore")

# %%
best_config = {'bert-base-uncased':{'lr':5.0e-5},
                'roberta-large':{'lr':5.0e-5, 'focalloss':True, 'gamma':8},
                'gpt2':{'lr':5.0e-5},
                'bigscience/bloom-560m':{'lr':5.0e-5, 'focalloss':True, 'gamma':8},
                'facebook/opt-350m':{'lr':1.0e-5},
                'EleutherAI/gpt-neo-1.3B':{'lr':5.0e-5}, 
                'microsoft/deberta-base':{'lr':1.0e-5},
                'microsoft/deberta-v2-xlarge':{'lr':1.0e-5, 'focalloss':True, 'gamma':4}}

# %%
results = {'test_acc':[],
           'test_f1':[],
           'eval_acc':[],
           'eval_f1':[],
           'wd':[]}

# %%
weight_decay = [0.01, 0.1]

for model_checkpoint in best_config.keys():
    for wd in weight_decay:
        print(f'Grid search {model_checkpoint}, learning rate {best_config[model_checkpoint]["lr"]}')
        data = ClimateDataset(model_to_train=4,model_checkpoint=model_checkpoint,dataset_url=flicc_path,batch_size=32)
        data.setup_dataloaders()
        model = ClassificationModel(model_checkpoint=data.model_checkpoint,num_labels=data.num_labels)
        trainer = Engine(epochs=30,labels=data.labels)
        trainer.model = model.model
        trainer.dataset_encoded = data.dataset_encoded
        test_acc, test_f1, eval_acc, eval_f1 = trainer.run(**best_config[model_checkpoint],
                                                            wd=wd,
                                                            train_dataloader=data.train_dataloader,
                                                            eval_dataloader=data.eval_dataloader,
                                                            test_dataloader=data.test_dataloader,
                                                            early_stop=3)
        results['test_acc'].append(test_acc)
        results['test_f1'].append(test_f1)
        results['eval_acc'].append(eval_acc)
        results['eval_f1'].append(eval_f1)
        results['wd'].append(wd)
        print('### '*10)
        print(results)
        print('### '*10)
        with torch.no_grad():
            torch.cuda.empty_cache()
        del data, model, trainer
        gc.collect()
# Out:
# Grid search bert-base-uncased, learning rate 5e-05
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# You're using a BertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# 1 / 30: Train Loss:	2.0826	Val Loss:	1.6531	Accuracy:	0.4989	F1:	0.3738 *
# 2 / 30: Train Loss:	1.2707	Val Loss:	1.3252	Accuracy:	0.5799	F1:	0.5194 *
# 3 / 30: Train Loss:	0.7319	Val Loss:	1.1258	Accuracy:	0.6324	F1:	0.5639 *
# 4 / 30: Train Loss:	0.3952	Val Loss:	1.4255	Accuracy:	0.5864	F1:	0.5423
# 5 / 30: Train Loss:	0.2623	Val Loss:	1.4625	Accuracy:	0.6236	F1:	0.5949 *
# 6 / 30: Train Loss:	0.1807	Val Loss:	1.3490	Accuracy:	0.6389	F1:	0.6072 *
# 7 / 30: Train Loss:	0.0986	Val Loss:	1.3551	Accuracy:	0.6324	F1:	0.5810
# 8 / 30: Train Loss:	0.0513	Val Loss:	1.3074	Accuracy:	0.6783	F1:	0.6467 *
# 9 / 30: Train Loss:	0.0241	Val Loss:	1.3179	Accuracy:	0.6849	F1:	0.6506 *
# 10 / 30: Train Loss:	0.0155	Val Loss:	1.3399	Accuracy:	0.6915	F1:	0.6668 *
# 11 / 30: Train Loss:	0.0142	Val Loss:	1.3720	Accuracy:	0.7024	F1:	0.6720 *
# 12 / 30: Train Loss:	0.0082	Val Loss:	1.4112	Accuracy:	0.6958	F1:	0.6679
# 13 / 30: Train Loss:	0.0067	Val Loss:	1.4371	Accuracy:	0.6915	F1:	0.6635
# 14 / 30: Train Loss:	0.0058	Val Loss:	1.4606	Accuracy:	0.6915	F1:	0.6624
# No improvement for 3 epochs. Stopping early.
# best (higgest macro f1-score) val results:
#                          precision    recall  f1-score   support
#
#              ad hominem       0.80      0.70      0.75        67
#                anecdote       0.88      0.84      0.86        43
#          cherry picking       0.65      0.71      0.68        56
#       conspiracy theory       0.71      0.87      0.78        39
#            fake experts       0.80      0.67      0.73        12
#            false choice       0.44      0.62      0.52        13
#       false equivalence       0.67      0.29      0.40        14
# impossible expectations       0.76      0.59      0.67        37
#       misrepresentation       0.61      0.53      0.56        38
#      oversimplification       0.85      0.64      0.73        36
#            single cause       0.69      0.74      0.71        57
#      slothful induction       0.59      0.82      0.69        45
#
#                accuracy                           0.70       457
#               macro avg       0.70      0.67      0.67       457
#            weighted avg       0.72      0.70      0.70       457
#
# test results:
#                          precision    recall  f1-score   support
#
#              ad hominem       0.72      0.78      0.75        37
#                anecdote       0.84      0.88      0.86        24
#          cherry picking       0.65      0.55      0.60        31
#       conspiracy theory       0.84      0.73      0.78        22
#            fake experts       1.00      0.71      0.83         7
#            false choice       0.36      0.57      0.44         7
#       false equivalence       0.50      0.25      0.33         8
# impossible expectations       0.76      0.62      0.68        21
#       misrepresentation       0.68      0.77      0.72        22
#      oversimplification       0.74      0.70      0.72        20
#            single cause       0.65      0.69      0.67        32
#      slothful induction       0.23      0.28      0.25        25
#
#                accuracy                           0.65       256
#               macro avg       0.66      0.63      0.64       256
#            weighted avg       0.67      0.65      0.66       256
#
# ### ### ### ### ### ### ### ### ### ###
# {'test_acc': [0.65234375], 'test_f1': [0.636725826724939], 'eval_acc': [0.7024070021881839], 'eval_f1': [0.6719505775235829], 'wd': [0.01]}
# ### ### ### ### ### ### ### ### ### ###
# Grid search bert-base-uncased, learning rate 5e-05
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# You're using a BertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# 1 / 30: Train Loss:	2.0645	Val Loss:	1.5972	Accuracy:	0.5098	F1:	0.4014 *
# 2 / 30: Train Loss:	1.2741	Val Loss:	1.2860	Accuracy:	0.5733	F1:	0.4912 *
# 3 / 30: Train Loss:	0.7838	Val Loss:	1.1558	Accuracy:	0.6346	F1:	0.5662 *
# 4 / 30: Train Loss:	0.4551	Val Loss:	1.2947	Accuracy:	0.6346	F1:	0.5817 *
# 5 / 30: Train Loss:	0.2872	Val Loss:	1.1718	Accuracy:	0.6761	F1:	0.6286 *
# 6 / 30: Train Loss:	0.1453	Val Loss:	1.2508	Accuracy:	0.6630	F1:	0.6413 *
# 7 / 30: Train Loss:	0.0624	Val Loss:	1.3152	Accuracy:	0.6849	F1:	0.6613 *
# 8 / 30: Train Loss:	0.0404	Val Loss:	1.3535	Accuracy:	0.6586	F1:	0.6180
# 9 / 30: Train Loss:	0.0338	Val Loss:	1.3915	Accuracy:	0.6652	F1:	0.6335
# 10 / 30: Train Loss:	0.0336	Val Loss:	1.5391	Accuracy:	0.6346	F1:	0.6125
# No improvement for 3 epochs. Stopping early.
# best (higgest macro f1-score) val results:
#                          precision    recall  f1-score   support
#
#              ad hominem       0.86      0.57      0.68        67
#                anecdote       0.97      0.84      0.90        43
#          cherry picking       0.67      0.71      0.69        56
#       conspiracy theory       0.74      0.82      0.78        39
#            fake experts       0.73      0.67      0.70        12
#            false choice       0.62      0.62      0.62        13
#       false equivalence       0.31      0.29      0.30        14
# impossible expectations       0.65      0.54      0.59        37
#       misrepresentation       0.63      0.58      0.60        38
#      oversimplification       0.79      0.64      0.71        36
#            single cause       0.85      0.77      0.81        57
#      slothful induction       0.43      0.84      0.57        45
#
#                accuracy                           0.68       457
#               macro avg       0.69      0.66      0.66       457
#            weighted avg       0.72      0.68      0.69       457
#
# test results:
#                          precision    recall  f1-score   support
#
#              ad hominem       0.78      0.68      0.72        37
#                anecdote       0.80      0.83      0.82        24
#          cherry picking       0.59      0.61      0.60        31
#       conspiracy theory       0.79      0.50      0.61        22
#            fake experts       1.00      0.86      0.92         7
#            false choice       0.33      0.57      0.42         7
#       false equivalence       0.25      0.25      0.25         8
# impossible expectations       0.68      0.71      0.70        21
#       misrepresentation       0.64      0.73      0.68        22
#      oversimplification       0.75      0.75      0.75        20
#            single cause       0.80      0.50      0.62        32
#      slothful induction       0.33      0.52      0.40        25
#
#                accuracy                           0.63       256
#               macro avg       0.65      0.63      0.62       256
#            weighted avg       0.67      0.63      0.64       256
#
# ### ### ### ### ### ### ### ### ### ###
# {'test_acc': [0.65234375, 0.6328125], 'test_f1': [0.636725826724939, 0.6244407982110255], 'eval_acc': [0.7024070021881839, 0.6849015317286652], 'eval_f1': [0.6719505775235829, 0.6612776420044664], 'wd': [0.01, 0.1]}
# ### ### ### ### ### ### ### ### ### ###
# Grid search roberta-large, learning rate 5e-05
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-large and are newly initialized: ['classifier.out_proj.bias', 'classifier.dense.weight', 'classifier.out_proj.weight', 'classifier.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# You're using a RobertaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# 1 / 30: Train Loss:	15.3941	Val Loss:	2.5120	Accuracy:	0.0306	F1:	0.0050 *
# 2 / 30: Train Loss:	15.4550	Val Loss:	2.5078	Accuracy:	0.0263	F1:	0.0043
# 3 / 30: Train Loss:	15.4795	Val Loss:	2.5130	Accuracy:	0.0284	F1:	0.0046
# 4 / 30: Train Loss:	15.3396	Val Loss:	2.5017	Accuracy:	0.0263	F1:	0.0043
# No improvement for 3 epochs. Stopping early.
# best (higgest macro f1-score) val results:
#                          precision    recall  f1-score   support
#
#              ad hominem       0.00      0.00      0.00        67
#                anecdote       0.00      0.00      0.00        43
#          cherry picking       0.00      0.00      0.00        56
#       conspiracy theory       0.00      0.00      0.00        39
#            fake experts       0.00      0.00      0.00        12
#            false choice       0.00      0.00      0.00        13
#       false equivalence       0.03      1.00      0.06        14
# impossible expectations       0.00      0.00      0.00        37
#       misrepresentation       0.00      0.00      0.00        38
#      oversimplification       0.00      0.00      0.00        36
#            single cause       0.00      0.00      0.00        57
#      slothful induction       0.00      0.00      0.00        45
#
#                accuracy                           0.03       457
#               macro avg       0.00      0.08      0.00       457
#            weighted avg       0.00      0.03      0.00       457
#
# test results:
#                          precision    recall  f1-score   support
#
#              ad hominem       0.00      0.00      0.00        37
#                anecdote       0.00      0.00      0.00        24
#          cherry picking       0.00      0.00      0.00        31
#       conspiracy theory       0.00      0.00      0.00        22
#            fake experts       0.00      0.00      0.00         7
#            false choice       0.00      0.00      0.00         7
#       false equivalence       0.03      1.00      0.06         8
# impossible expectations       0.00      0.00      0.00        21
#       misrepresentation       0.00      0.00      0.00        22
#      oversimplification       0.00      0.00      0.00        20
#            single cause       0.00      0.00      0.00        32
#      slothful induction       0.00      0.00      0.00        25
#
#                accuracy                           0.03       256
#               macro avg       0.00      0.08      0.01       256
#            weighted avg       0.00      0.03      0.00       256
#
# ### ### ### ### ### ### ### ### ### ###
# {'test_acc': [0.65234375, 0.6328125, 0.03125], 'test_f1': [0.636725826724939, 0.6244407982110255, 0.005050505050505051], 'eval_acc': [0.7024070021881839, 0.6849015317286652, 0.030634573304157548], 'eval_f1': [0.6719505775235829, 0.6612776420044664, 0.004953998584571833], 'wd': [0.01, 0.1, 0.01]}
# ### ### ### ### ### ### ### ### ### ###
# Grid search roberta-large, learning rate 5e-05
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-large and are newly initialized: ['classifier.out_proj.bias', 'classifier.dense.weight', 'classifier.out_proj.weight', 'classifier.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# You're using a RobertaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# 1 / 30: Train Loss:	15.6421	Val Loss:	2.5155	Accuracy:	0.0263	F1:	0.0043 *
# 2 / 30: Train Loss:	15.5149	Val Loss:	2.5249	Accuracy:	0.0263	F1:	0.0043
# 3 / 30: Train Loss:	15.6829	Val Loss:	2.5278	Accuracy:	0.0284	F1:	0.0046 *
# 4 / 30: Train Loss:	15.4163	Val Loss:	2.5176	Accuracy:	0.0263	F1:	0.0043
# 5 / 30: Train Loss:	15.4339	Val Loss:	2.5215	Accuracy:	0.0263	F1:	0.0043
# 6 / 30: Train Loss:	15.4083	Val Loss:	2.5245	Accuracy:	0.0263	F1:	0.0043
# No improvement for 3 epochs. Stopping early.
# best (higgest macro f1-score) val results:
#                          precision    recall  f1-score   support
#
#              ad hominem       0.00      0.00      0.00        67
#                anecdote       0.00      0.00      0.00        43
#          cherry picking       0.00      0.00      0.00        56
#       conspiracy theory       0.00      0.00      0.00        39
#            fake experts       0.00      0.00      0.00        12
#            false choice       0.03      1.00      0.06        13
#       false equivalence       0.00      0.00      0.00        14
# impossible expectations       0.00      0.00      0.00        37
#       misrepresentation       0.00      0.00      0.00        38
#      oversimplification       0.00      0.00      0.00        36
#            single cause       0.00      0.00      0.00        57
#      slothful induction       0.00      0.00      0.00        45
#
#                accuracy                           0.03       457
#               macro avg       0.00      0.08      0.00       457
#            weighted avg       0.00      0.03      0.00       457
#
# test results:
#                          precision    recall  f1-score   support
#
#              ad hominem       0.00      0.00      0.00        37
#                anecdote       0.00      0.00      0.00        24
#          cherry picking       0.00      0.00      0.00        31
#       conspiracy theory       0.00      0.00      0.00        22
#            fake experts       0.00      0.00      0.00         7
#            false choice       0.03      1.00      0.05         7
#       false equivalence       0.00      0.00      0.00         8
# impossible expectations       0.00      0.00      0.00        21
#       misrepresentation       0.00      0.00      0.00        22
#      oversimplification       0.00      0.00      0.00        20
#            single cause       0.00      0.00      0.00        32
#      slothful induction       0.00      0.00      0.00        25
#
#                accuracy                           0.03       256
#               macro avg       0.00      0.08      0.00       256
#            weighted avg       0.00      0.03      0.00       256
#
# ### ### ### ### ### ### ### ### ### ###
# {'test_acc': [0.65234375, 0.6328125, 0.03125, 0.02734375], 'test_f1': [0.636725826724939, 0.6244407982110255, 0.005050505050505051, 0.004435994930291508], 'eval_acc': [0.7024070021881839, 0.6849015317286652, 0.030634573304157548, 0.028446389496717725], 'eval_f1': [0.6719505775235829, 0.6612776420044664, 0.004953998584571833, 0.004609929078014185], 'wd': [0.01, 0.1, 0.01, 0.1]}
# ### ### ### ### ### ### ### ### ### ###
# Grid search gpt2, learning rate 5e-05
# Some weights of GPT2ForSequenceClassification were not initialized from the model checkpoint at gpt2 and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# You're using a GPT2TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# 1 / 30: Train Loss:	2.6266	Val Loss:	2.3424	Accuracy:	0.2013	F1:	0.0824 *
# 2 / 30: Train Loss:	2.3336	Val Loss:	2.2754	Accuracy:	0.2276	F1:	0.1327 *
# 3 / 30: Train Loss:	2.1796	Val Loss:	2.0538	Accuracy:	0.3107	F1:	0.2502 *
# 4 / 30: Train Loss:	1.7931	Val Loss:	1.7489	Accuracy:	0.4048	F1:	0.3452 *
# 5 / 30: Train Loss:	1.4814	Val Loss:	1.5686	Accuracy:	0.4617	F1:	0.4122 *
# 6 / 30: Train Loss:	1.2192	Val Loss:	1.5846	Accuracy:	0.4705	F1:	0.4149 *
# 7 / 30: Train Loss:	1.0167	Val Loss:	1.6382	Accuracy:	0.4923	F1:	0.4706 *
# 8 / 30: Train Loss:	0.8113	Val Loss:	1.8563	Accuracy:	0.4858	F1:	0.4760 *
# 9 / 30: Train Loss:	0.7201	Val Loss:	1.7222	Accuracy:	0.4967	F1:	0.4909 *
# 10 / 30: Train Loss:	0.4860	Val Loss:	1.8272	Accuracy:	0.5252	F1:	0.5069 *
# 11 / 30: Train Loss:	0.3716	Val Loss:	2.0418	Accuracy:	0.4836	F1:	0.4763
# 12 / 30: Train Loss:	0.2644	Val Loss:	1.7428	Accuracy:	0.5492	F1:	0.5360 *
# 13 / 30: Train Loss:	0.1687	Val Loss:	1.8002	Accuracy:	0.5514	F1:	0.5405 *
# 14 / 30: Train Loss:	0.1315	Val Loss:	1.8810	Accuracy:	0.5689	F1:	0.5587 *
# 15 / 30: Train Loss:	0.1249	Val Loss:	1.7965	Accuracy:	0.5821	F1:	0.5774 *
# 16 / 30: Train Loss:	0.0825	Val Loss:	1.8755	Accuracy:	0.5492	F1:	0.5349
# 17 / 30: Train Loss:	0.0575	Val Loss:	1.8341	Accuracy:	0.5711	F1:	0.5545
# 18 / 30: Train Loss:	0.0479	Val Loss:	2.0133	Accuracy:	0.5361	F1:	0.5262
# No improvement for 3 epochs. Stopping early.
# best (higgest macro f1-score) val results:
#                          precision    recall  f1-score   support
#
#              ad hominem       0.74      0.51      0.60        67
#                anecdote       0.79      0.79      0.79        43
#          cherry picking       0.82      0.25      0.38        56
#       conspiracy theory       0.62      0.82      0.70        39
#            fake experts       0.70      0.58      0.64        12
#            false choice       0.45      0.77      0.57        13
#       false equivalence       0.47      0.50      0.48        14
# impossible expectations       0.54      0.54      0.54        37
#       misrepresentation       0.37      0.55      0.44        38
#      oversimplification       0.62      0.64      0.63        36
#            single cause       0.56      0.61      0.58        57
#      slothful induction       0.50      0.64      0.56        45
#
#                accuracy                           0.58       457
#               macro avg       0.60      0.60      0.58       457
#            weighted avg       0.62      0.58      0.58       457
#
# test results:
#                          precision    recall  f1-score   support
#
#              ad hominem       0.79      0.62      0.70        37
#                anecdote       0.75      0.88      0.81        24
#          cherry picking       0.79      0.35      0.49        31
#       conspiracy theory       0.73      0.86      0.79        22
#            fake experts       1.00      0.57      0.73         7
#            false choice       0.18      0.29      0.22         7
#       false equivalence       0.50      0.25      0.33         8
# impossible expectations       0.70      0.76      0.73        21
#       misrepresentation       0.47      0.64      0.54        22
#      oversimplification       0.46      0.80      0.58        20
#            single cause       0.52      0.53      0.52        32
#      slothful induction       0.47      0.36      0.41        25
#
#                accuracy                           0.60       256
#               macro avg       0.61      0.58      0.57       256
#            weighted avg       0.63      0.60      0.60       256
#
# ### ### ### ### ### ### ### ### ### ###
# {'test_acc': [0.65234375, 0.6328125, 0.03125, 0.02734375, 0.6015625], 'test_f1': [0.636725826724939, 0.6244407982110255, 0.005050505050505051, 0.004435994930291508, 0.5706471768971769], 'eval_acc': [0.7024070021881839, 0.6849015317286652, 0.030634573304157548, 0.028446389496717725, 0.5820568927789934], 'eval_f1': [0.6719505775235829, 0.6612776420044664, 0.004953998584571833, 0.004609929078014185, 0.5774249734155712], 'wd': [0.01, 0.1, 0.01, 0.1, 0.01]}
# ### ### ### ### ### ### ### ### ### ###
# Grid search gpt2, learning rate 5e-05
# Some weights of GPT2ForSequenceClassification were not initialized from the model checkpoint at gpt2 and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# You're using a GPT2TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# 1 / 30: Train Loss:	2.6265	Val Loss:	2.3423	Accuracy:	0.2013	F1:	0.0824 *
# 2 / 30: Train Loss:	2.3334	Val Loss:	2.2756	Accuracy:	0.2276	F1:	0.1327 *
# 3 / 30: Train Loss:	2.1786	Val Loss:	2.0516	Accuracy:	0.3107	F1:	0.2493 *
# 4 / 30: Train Loss:	1.7914	Val Loss:	1.7472	Accuracy:	0.4026	F1:	0.3418 *
# 5 / 30: Train Loss:	1.4814	Val Loss:	1.5708	Accuracy:	0.4617	F1:	0.4110 *
# 6 / 30: Train Loss:	1.2124	Val Loss:	1.5917	Accuracy:	0.4770	F1:	0.4261 *
# 7 / 30: Train Loss:	1.0050	Val Loss:	1.6452	Accuracy:	0.4814	F1:	0.4554 *
# 8 / 30: Train Loss:	0.7938	Val Loss:	1.8781	Accuracy:	0.4945	F1:	0.4822 *
# 9 / 30: Train Loss:	0.7139	Val Loss:	1.7647	Accuracy:	0.5120	F1:	0.4978 *
# 10 / 30: Train Loss:	0.4824	Val Loss:	1.7497	Accuracy:	0.5558	F1:	0.5337 *
# 11 / 30: Train Loss:	0.3627	Val Loss:	2.1020	Accuracy:	0.4880	F1:	0.4735
# 12 / 30: Train Loss:	0.2540	Val Loss:	1.7301	Accuracy:	0.5470	F1:	0.5303
# 13 / 30: Train Loss:	0.1625	Val Loss:	1.7471	Accuracy:	0.5492	F1:	0.5268
# No improvement for 3 epochs. Stopping early.
# best (higgest macro f1-score) val results:
#                          precision    recall  f1-score   support
#
#              ad hominem       0.78      0.31      0.45        67
#                anecdote       0.97      0.67      0.79        43
#          cherry picking       0.76      0.39      0.52        56
#       conspiracy theory       0.54      0.79      0.65        39
#            fake experts       0.50      0.42      0.45        12
#            false choice       0.33      0.38      0.36        13
#       false equivalence       0.32      0.57      0.41        14
# impossible expectations       0.49      0.54      0.51        37
#       misrepresentation       0.39      0.47      0.43        38
#      oversimplification       0.77      0.56      0.65        36
#            single cause       0.45      0.86      0.59        57
#      slothful induction       0.63      0.58      0.60        45
#
#                accuracy                           0.56       457
#               macro avg       0.58      0.55      0.53       457
#            weighted avg       0.63      0.56      0.55       457
#
# test results:
#                          precision    recall  f1-score   support
#
#              ad hominem       1.00      0.38      0.55        37
#                anecdote       0.83      0.83      0.83        24
#          cherry picking       0.47      0.23      0.30        31
#       conspiracy theory       0.56      0.91      0.69        22
#            fake experts       1.00      0.43      0.60         7
#            false choice       0.17      0.29      0.21         7
#       false equivalence       0.18      0.25      0.21         8
# impossible expectations       0.67      0.67      0.67        21
#       misrepresentation       0.55      0.55      0.55        22
#      oversimplification       0.54      0.70      0.61        20
#            single cause       0.41      0.75      0.53        32
#      slothful induction       0.43      0.24      0.31        25
#
#                accuracy                           0.54       256
#               macro avg       0.57      0.52      0.50       256
#            weighted avg       0.60      0.54      0.53       256
#
# ### ### ### ### ### ### ### ### ### ###
# {'test_acc': [0.65234375, 0.6328125, 0.03125, 0.02734375, 0.6015625, 0.5390625], 'test_f1': [0.636725826724939, 0.6244407982110255, 0.005050505050505051, 0.004435994930291508, 0.5706471768971769, 0.5049375897147445], 'eval_acc': [0.7024070021881839, 0.6849015317286652, 0.030634573304157548, 0.028446389496717725, 0.5820568927789934, 0.5557986870897156], 'eval_f1': [0.6719505775235829, 0.6612776420044664, 0.004953998584571833, 0.004609929078014185, 0.5774249734155712, 0.5337320762079748], 'wd': [0.01, 0.1, 0.01, 0.1, 0.01, 0.1]}
# ### ### ### ### ### ### ### ### ### ###
# Grid search bigscience/bloom-560m, learning rate 5e-05
# Some weights of BloomForSequenceClassification were not initialized from the model checkpoint at bigscience/bloom-560m and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# You're using a BloomTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# 1 / 30: Train Loss:	106.9985	Val Loss:	2.2956	Accuracy:	0.3239	F1:	0.2751 *
# 2 / 30: Train Loss:	9.8229	Val Loss:	1.9329	Accuracy:	0.3829	F1:	0.3847 *
# 3 / 30: Train Loss:	5.7207	Val Loss:	2.3164	Accuracy:	0.4923	F1:	0.4510 *
# 4 / 30: Train Loss:	4.5515	Val Loss:	2.3392	Accuracy:	0.4792	F1:	0.4556 *
# 5 / 30: Train Loss:	6.7059	Val Loss:	2.7389	Accuracy:	0.4420	F1:	0.4098
# 6 / 30: Train Loss:	3.0667	Val Loss:	2.0658	Accuracy:	0.5098	F1:	0.5082 *
# 7 / 30: Train Loss:	1.3043	Val Loss:	2.4922	Accuracy:	0.4923	F1:	0.4757
# 8 / 30: Train Loss:	1.8395	Val Loss:	4.9563	Accuracy:	0.2713	F1:	0.2961
# 9 / 30: Train Loss:	3.8361	Val Loss:	2.7184	Accuracy:	0.4617	F1:	0.4325
# No improvement for 3 epochs. Stopping early.
# best (higgest macro f1-score) val results:
#                          precision    recall  f1-score   support
#
#              ad hominem       0.50      0.66      0.57        67
#                anecdote       0.87      0.47      0.61        43
#          cherry picking       0.42      0.59      0.49        56
#       conspiracy theory       0.77      0.51      0.62        39
#            fake experts       0.83      0.42      0.56        12
#            false choice       0.33      0.77      0.47        13
#       false equivalence       0.17      0.71      0.28        14
# impossible expectations       0.71      0.46      0.56        37
#       misrepresentation       0.63      0.45      0.52        38
#      oversimplification       0.82      0.64      0.72        36
#            single cause       0.48      0.47      0.48        57
#      slothful induction       0.54      0.16      0.24        45
#
#                accuracy                           0.51       457
#               macro avg       0.59      0.52      0.51       457
#            weighted avg       0.60      0.51      0.52       457
#
# test results:
#                          precision    recall  f1-score   support
#
#              ad hominem       0.61      0.76      0.67        37
#                anecdote       0.87      0.54      0.67        24
#          cherry picking       0.35      0.45      0.39        31
#       conspiracy theory       0.78      0.32      0.45        22
#            fake experts       0.75      0.43      0.55         7
#            false choice       0.21      0.43      0.29         7
#       false equivalence       0.12      0.62      0.20         8
# impossible expectations       0.75      0.57      0.65        21
#       misrepresentation       0.61      0.50      0.55        22
#      oversimplification       0.64      0.70      0.67        20
#            single cause       0.54      0.47      0.50        32
#      slothful induction       0.00      0.00      0.00        25
#
#                accuracy                           0.49       256
#               macro avg       0.52      0.48      0.46       256
#            weighted avg       0.54      0.49      0.49       256
#
# ### ### ### ### ### ### ### ### ### ###
# {'test_acc': [0.65234375, 0.6328125, 0.03125, 0.02734375, 0.6015625, 0.5390625, 0.48828125], 'test_f1': [0.636725826724939, 0.6244407982110255, 0.005050505050505051, 0.004435994930291508, 0.5706471768971769, 0.5049375897147445, 0.4649922616760826], 'eval_acc': [0.7024070021881839, 0.6849015317286652, 0.030634573304157548, 0.028446389496717725, 0.5820568927789934, 0.5557986870897156, 0.5098468271334792], 'eval_f1': [0.6719505775235829, 0.6612776420044664, 0.004953998584571833, 0.004609929078014185, 0.5774249734155712, 0.5337320762079748, 0.5082194559634832], 'wd': [0.01, 0.1, 0.01, 0.1, 0.01, 0.1, 0.01]}
# ### ### ### ### ### ### ### ### ### ###
# Grid search bigscience/bloom-560m, learning rate 5e-05
# Some weights of BloomForSequenceClassification were not initialized from the model checkpoint at bigscience/bloom-560m and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# You're using a BloomTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# 1 / 30: Train Loss:	105.3171	Val Loss:	2.0144	Accuracy:	0.3173	F1:	0.2776 *
# 2 / 30: Train Loss:	11.3037	Val Loss:	2.7408	Accuracy:	0.2998	F1:	0.2455
# 3 / 30: Train Loss:	4.5550	Val Loss:	1.8157	Accuracy:	0.5208	F1:	0.5237 *
# 4 / 30: Train Loss:	5.0867	Val Loss:	2.2948	Accuracy:	0.4551	F1:	0.3902
# 5 / 30: Train Loss:	3.6427	Val Loss:	2.1893	Accuracy:	0.5055	F1:	0.4604
# 6 / 30: Train Loss:	3.0571	Val Loss:	3.1745	Accuracy:	0.4004	F1:	0.4168
# No improvement for 3 epochs. Stopping early.
# best (higgest macro f1-score) val results:
#                          precision    recall  f1-score   support
#
#              ad hominem       0.60      0.60      0.60        67
#                anecdote       0.82      0.74      0.78        43
#          cherry picking       0.51      0.43      0.47        56
#       conspiracy theory       0.84      0.54      0.66        39
#            fake experts       0.50      0.67      0.57        12
#            false choice       0.78      0.54      0.64        13
#       false equivalence       0.30      0.21      0.25        14
# impossible expectations       0.46      0.73      0.56        37
#       misrepresentation       0.58      0.29      0.39        38
#      oversimplification       0.66      0.58      0.62        36
#            single cause       0.83      0.26      0.40        57
#      slothful induction       0.25      0.64      0.36        45
#
#                accuracy                           0.52       457
#               macro avg       0.59      0.52      0.52       457
#            weighted avg       0.61      0.52      0.53       457
#
# test results:
#                          precision    recall  f1-score   support
#
#              ad hominem       0.59      0.51      0.55        37
#                anecdote       0.76      0.79      0.78        24
#          cherry picking       0.60      0.48      0.54        31
#       conspiracy theory       0.67      0.36      0.47        22
#            fake experts       0.75      0.86      0.80         7
#            false choice       0.67      0.29      0.40         7
#       false equivalence       0.33      0.25      0.29         8
# impossible expectations       0.58      0.90      0.70        21
#       misrepresentation       0.70      0.32      0.44        22
#      oversimplification       0.59      0.50      0.54        20
#            single cause       0.86      0.19      0.31        32
#      slothful induction       0.22      0.68      0.33        25
#
#                accuracy                           0.51       256
#               macro avg       0.61      0.51      0.51       256
#            weighted avg       0.62      0.51      0.51       256
#
# ### ### ### ### ### ### ### ### ### ###
# {'test_acc': [0.65234375, 0.6328125, 0.03125, 0.02734375, 0.6015625, 0.5390625, 0.48828125, 0.5078125], 'test_f1': [0.636725826724939, 0.6244407982110255, 0.005050505050505051, 0.004435994930291508, 0.5706471768971769, 0.5049375897147445, 0.4649922616760826, 0.5114821073167227], 'eval_acc': [0.7024070021881839, 0.6849015317286652, 0.030634573304157548, 0.028446389496717725, 0.5820568927789934, 0.5557986870897156, 0.5098468271334792, 0.5207877461706784], 'eval_f1': [0.6719505775235829, 0.6612776420044664, 0.004953998584571833, 0.004609929078014185, 0.5774249734155712, 0.5337320762079748, 0.5082194559634832, 0.5236603978190266], 'wd': [0.01, 0.1, 0.01, 0.1, 0.01, 0.1, 0.01, 0.1]}
# ### ### ### ### ### ### ### ### ### ###
# Grid search facebook/opt-350m, learning rate 1e-05
# Some weights of OPTForSequenceClassification were not initialized from the model checkpoint at facebook/opt-350m and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# You're using a GPT2TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# 1 / 30: Train Loss:	2.5056	Val Loss:	1.9545	Accuracy:	0.2888	F1:	0.1962 *
# 2 / 30: Train Loss:	2.1424	Val Loss:	2.2655	Accuracy:	0.2254	F1:	0.1229
# 3 / 30: Train Loss:	2.1910	Val Loss:	2.4247	Accuracy:	0.1751	F1:	0.0885
# 4 / 30: Train Loss:	2.4311	Val Loss:	2.3942	Accuracy:	0.1466	F1:	0.0818
# No improvement for 3 epochs. Stopping early.
# best (higgest macro f1-score) val results:
#                          precision    recall  f1-score   support
#
#              ad hominem       0.44      0.37      0.40        67
#                anecdote       0.59      0.77      0.67        43
#          cherry picking       0.54      0.27      0.36        56
#       conspiracy theory       0.17      0.64      0.26        39
#            fake experts       0.00      0.00      0.00        12
#            false choice       0.00      0.00      0.00        13
#       false equivalence       0.00      0.00      0.00        14
# impossible expectations       0.21      0.59      0.31        37
#       misrepresentation       0.18      0.24      0.21        38
#      oversimplification       0.75      0.08      0.15        36
#            single cause       0.00      0.00      0.00        57
#      slothful induction       0.00      0.00      0.00        45
#
#                accuracy                           0.29       457
#               macro avg       0.24      0.25      0.20       457
#            weighted avg       0.29      0.29      0.24       457
#
# test results:
#                          precision    recall  f1-score   support
#
#              ad hominem       0.58      0.41      0.48        37
#                anecdote       0.56      0.75      0.64        24
#          cherry picking       0.37      0.23      0.28        31
#       conspiracy theory       0.16      0.64      0.26        22
#            fake experts       0.00      0.00      0.00         7
#            false choice       0.00      0.00      0.00         7
#       false equivalence       1.00      0.12      0.22         8
# impossible expectations       0.22      0.71      0.33        21
#       misrepresentation       0.31      0.23      0.26        22
#      oversimplification       0.33      0.05      0.09        20
#            single cause       0.00      0.00      0.00        32
#      slothful induction       0.00      0.00      0.00        25
#
#                accuracy                           0.30       256
#               macro avg       0.29      0.26      0.21       256
#            weighted avg       0.30      0.30      0.25       256
#
# ### ### ### ### ### ### ### ### ### ###
# {'test_acc': [0.65234375, 0.6328125, 0.03125, 0.02734375, 0.6015625, 0.5390625, 0.48828125, 0.5078125, 0.296875], 'test_f1': [0.636725826724939, 0.6244407982110255, 0.005050505050505051, 0.004435994930291508, 0.5706471768971769, 0.5049375897147445, 0.4649922616760826, 0.5114821073167227, 0.21346652708534175], 'eval_acc': [0.7024070021881839, 0.6849015317286652, 0.030634573304157548, 0.028446389496717725, 0.5820568927789934, 0.5557986870897156, 0.5098468271334792, 0.5207877461706784, 0.2888402625820569], 'eval_f1': [0.6719505775235829, 0.6612776420044664, 0.004953998584571833, 0.004609929078014185, 0.5774249734155712, 0.5337320762079748, 0.5082194559634832, 0.5236603978190266, 0.1962318403678687], 'wd': [0.01, 0.1, 0.01, 0.1, 0.01, 0.1, 0.01, 0.1, 0.01]}
# ### ### ### ### ### ### ### ### ### ###
# Grid search facebook/opt-350m, learning rate 1e-05
# Some weights of OPTForSequenceClassification were not initialized from the model checkpoint at facebook/opt-350m and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# You're using a GPT2TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# 1 / 30: Train Loss:	2.5047	Val Loss:	1.9779	Accuracy:	0.2801	F1:	0.1877 *
# 2 / 30: Train Loss:	2.2058	Val Loss:	2.3489	Accuracy:	0.1751	F1:	0.0994
# 3 / 30: Train Loss:	2.5033	Val Loss:	2.3760	Accuracy:	0.1488	F1:	0.0489
# 4 / 30: Train Loss:	2.4035	Val Loss:	2.3347	Accuracy:	0.1729	F1:	0.0632
# No improvement for 3 epochs. Stopping early.
# best (higgest macro f1-score) val results:
#                          precision    recall  f1-score   support
#
#              ad hominem       0.46      0.33      0.38        67
#                anecdote       0.61      0.77      0.68        43
#          cherry picking       0.53      0.16      0.25        56
#       conspiracy theory       0.17      0.67      0.27        39
#            fake experts       0.00      0.00      0.00        12
#            false choice       0.00      0.00      0.00        13
#       false equivalence       0.00      0.00      0.00        14
# impossible expectations       0.20      0.70      0.31        37
#       misrepresentation       0.19      0.24      0.21        38
#      oversimplification       0.75      0.08      0.15        36
#            single cause       0.00      0.00      0.00        57
#      slothful induction       0.00      0.00      0.00        45
#
#                accuracy                           0.28       457
#               macro avg       0.24      0.25      0.19       457
#            weighted avg       0.30      0.28      0.23       457
#
# test results:
#                          precision    recall  f1-score   support
#
#              ad hominem       0.62      0.43      0.51        37
#                anecdote       0.58      0.75      0.65        24
#          cherry picking       0.46      0.19      0.27        31
#       conspiracy theory       0.17      0.64      0.27        22
#            fake experts       0.00      0.00      0.00         7
#            false choice       0.00      0.00      0.00         7
#       false equivalence       1.00      0.12      0.22         8
# impossible expectations       0.21      0.76      0.32        21
#       misrepresentation       0.26      0.23      0.24        22
#      oversimplification       0.50      0.05      0.09        20
#            single cause       0.00      0.00      0.00        32
#      slothful induction       0.00      0.00      0.00        25
#
#                accuracy                           0.30       256
#               macro avg       0.32      0.26      0.22       256
#            weighted avg       0.32      0.30      0.25       256
#
# ### ### ### ### ### ### ### ### ### ###
# {'test_acc': [0.65234375, 0.6328125, 0.03125, 0.02734375, 0.6015625, 0.5390625, 0.48828125, 0.5078125, 0.296875, 0.30078125], 'test_f1': [0.636725826724939, 0.6244407982110255, 0.005050505050505051, 0.004435994930291508, 0.5706471768971769, 0.5049375897147445, 0.4649922616760826, 0.5114821073167227, 0.21346652708534175, 0.21517849810532738], 'eval_acc': [0.7024070021881839, 0.6849015317286652, 0.030634573304157548, 0.028446389496717725, 0.5820568927789934, 0.5557986870897156, 0.5098468271334792, 0.5207877461706784, 0.2888402625820569, 0.2800875273522976], 'eval_f1': [0.6719505775235829, 0.6612776420044664, 0.004953998584571833, 0.004609929078014185, 0.5774249734155712, 0.5337320762079748, 0.5082194559634832, 0.5236603978190266, 0.1962318403678687, 0.18768070103806286], 'wd': [0.01, 0.1, 0.01, 0.1, 0.01, 0.1, 0.01, 0.1, 0.01, 0.1]}
# ### ### ### ### ### ### ### ### ### ###
# Grid search EleutherAI/gpt-neo-1.3B, learning rate 5e-05
# Some weights of GPTNeoForSequenceClassification were not initialized from the model checkpoint at EleutherAI/gpt-neo-1.3B and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# You're using a GPT2TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# 1 / 30: Train Loss:	2.2442	Val Loss:	1.5294	Accuracy:	0.4792	F1:	0.3912 *
# 2 / 30: Train Loss:	1.1459	Val Loss:	1.4352	Accuracy:	0.5317	F1:	0.5205 *
# 3 / 30: Train Loss:	0.3086	Val Loss:	1.8105	Accuracy:	0.5339	F1:	0.5146
# 4 / 30: Train Loss:	0.1979	Val Loss:	1.9450	Accuracy:	0.5624	F1:	0.5457 *
# 5 / 30: Train Loss:	0.0969	Val Loss:	1.8695	Accuracy:	0.5470	F1:	0.5191
# 6 / 30: Train Loss:	0.0780	Val Loss:	1.8435	Accuracy:	0.5733	F1:	0.5599 *
# 7 / 30: Train Loss:	0.0723	Val Loss:	1.8086	Accuracy:	0.5842	F1:	0.5861 *
# 8 / 30: Train Loss:	0.0649	Val Loss:	1.8108	Accuracy:	0.5864	F1:	0.5859
# 9 / 30: Train Loss:	0.0691	Val Loss:	1.8164	Accuracy:	0.5908	F1:	0.5893 *
# 10 / 30: Train Loss:	0.0607	Val Loss:	1.8229	Accuracy:	0.5996	F1:	0.5971 *
# 11 / 30: Train Loss:	0.0604	Val Loss:	1.8296	Accuracy:	0.6039	F1:	0.6040 *
# 12 / 30: Train Loss:	0.0532	Val Loss:	1.8381	Accuracy:	0.6061	F1:	0.6057 *
# 13 / 30: Train Loss:	0.0469	Val Loss:	1.8469	Accuracy:	0.5974	F1:	0.5955
# 14 / 30: Train Loss:	0.0507	Val Loss:	1.8954	Accuracy:	0.5711	F1:	0.5687
# 15 / 30: Train Loss:	0.0586	Val Loss:	2.1381	Accuracy:	0.5492	F1:	0.5359
# No improvement for 3 epochs. Stopping early.
# best (higgest macro f1-score) val results:
#                          precision    recall  f1-score   support
#
#              ad hominem       0.54      0.66      0.59        67
#                anecdote       0.76      0.74      0.75        43
#          cherry picking       0.52      0.66      0.58        56
#       conspiracy theory       0.65      0.67      0.66        39
#            fake experts       0.89      0.67      0.76        12
#            false choice       0.70      0.54      0.61        13
#       false equivalence       0.80      0.29      0.42        14
# impossible expectations       0.62      0.54      0.58        37
#       misrepresentation       0.52      0.45      0.48        38
#      oversimplification       0.79      0.64      0.71        36
#            single cause       0.63      0.65      0.64        57
#      slothful induction       0.48      0.49      0.48        45
#
#                accuracy                           0.61       457
#               macro avg       0.66      0.58      0.61       457
#            weighted avg       0.62      0.61      0.61       457
#
# test results:
#                          precision    recall  f1-score   support
#
#              ad hominem       0.59      0.70      0.64        37
#                anecdote       0.90      0.79      0.84        24
#          cherry picking       0.56      0.65      0.60        31
#       conspiracy theory       0.63      0.55      0.59        22
#            fake experts       0.80      0.57      0.67         7
#            false choice       0.50      0.29      0.36         7
#       false equivalence       0.67      0.25      0.36         8
# impossible expectations       0.68      0.62      0.65        21
#       misrepresentation       0.62      0.45      0.53        22
#      oversimplification       0.56      0.75      0.64        20
#            single cause       0.56      0.72      0.63        32
#      slothful induction       0.38      0.32      0.35        25
#
#                accuracy                           0.60       256
#               macro avg       0.62      0.55      0.57       256
#            weighted avg       0.61      0.60      0.60       256
#
# ### ### ### ### ### ### ### ### ### ###
# {'test_acc': [0.65234375, 0.6328125, 0.03125, 0.02734375, 0.6015625, 0.5390625, 0.48828125, 0.5078125, 0.296875, 0.30078125, 0.6015625], 'test_f1': [0.636725826724939, 0.6244407982110255, 0.005050505050505051, 0.004435994930291508, 0.5706471768971769, 0.5049375897147445, 0.4649922616760826, 0.5114821073167227, 0.21346652708534175, 0.21517849810532738, 0.5712763884274571], 'eval_acc': [0.7024070021881839, 0.6849015317286652, 0.030634573304157548, 0.028446389496717725, 0.5820568927789934, 0.5557986870897156, 0.5098468271334792, 0.5207877461706784, 0.2888402625820569, 0.2800875273522976, 0.6061269146608315], 'eval_f1': [0.6719505775235829, 0.6612776420044664, 0.004953998584571833, 0.004609929078014185, 0.5774249734155712, 0.5337320762079748, 0.5082194559634832, 0.5236603978190266, 0.1962318403678687, 0.18768070103806286, 0.605651420019509], 'wd': [0.01, 0.1, 0.01, 0.1, 0.01, 0.1, 0.01, 0.1, 0.01, 0.1, 0.01]}
# ### ### ### ### ### ### ### ### ### ###
# Grid search EleutherAI/gpt-neo-1.3B, learning rate 5e-05
# Some weights of GPTNeoForSequenceClassification were not initialized from the model checkpoint at EleutherAI/gpt-neo-1.3B and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# You're using a GPT2TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# 1 / 30: Train Loss:	2.1494	Val Loss:	1.4742	Accuracy:	0.4989	F1:	0.4383 *
# 2 / 30: Train Loss:	0.9676	Val Loss:	1.3882	Accuracy:	0.5514	F1:	0.5557 *
# 3 / 30: Train Loss:	0.2490	Val Loss:	1.6440	Accuracy:	0.5646	F1:	0.5326
# 4 / 30: Train Loss:	0.1344	Val Loss:	1.7704	Accuracy:	0.5580	F1:	0.5603 *
# 5 / 30: Train Loss:	0.1499	Val Loss:	1.6068	Accuracy:	0.5799	F1:	0.5812 *
# 6 / 30: Train Loss:	0.0823	Val Loss:	1.6461	Accuracy:	0.6149	F1:	0.5870 *
# 7 / 30: Train Loss:	0.1085	Val Loss:	2.0847	Accuracy:	0.5317	F1:	0.5068
# 8 / 30: Train Loss:	0.1490	Val Loss:	1.6824	Accuracy:	0.6193	F1:	0.6077 *
# 9 / 30: Train Loss:	0.0504	Val Loss:	1.9631	Accuracy:	0.5755	F1:	0.5819
# 10 / 30: Train Loss:	0.0351	Val Loss:	1.9194	Accuracy:	0.6236	F1:	0.6057
# 11 / 30: Train Loss:	0.0095	Val Loss:	1.8912	Accuracy:	0.5974	F1:	0.5833
# No improvement for 3 epochs. Stopping early.
# best (higgest macro f1-score) val results:
#                          precision    recall  f1-score   support
#
#              ad hominem       0.52      0.55      0.54        67
#                anecdote       0.79      0.77      0.78        43
#          cherry picking       0.57      0.62      0.60        56
#       conspiracy theory       0.74      0.74      0.74        39
#            fake experts       0.77      0.83      0.80        12
#            false choice       0.45      0.69      0.55        13
#       false equivalence       0.20      0.21      0.21        14
# impossible expectations       0.73      0.51      0.60        37
#       misrepresentation       0.63      0.50      0.56        38
#      oversimplification       0.86      0.53      0.66        36
#            single cause       0.66      0.68      0.67        57
#      slothful induction       0.53      0.69      0.60        45
#
#                accuracy                           0.62       457
#               macro avg       0.62      0.61      0.61       457
#            weighted avg       0.64      0.62      0.62       457
#
# test results:
#                          precision    recall  f1-score   support
#
#              ad hominem       0.68      0.73      0.70        37
#                anecdote       0.82      0.96      0.88        24
#          cherry picking       0.53      0.52      0.52        31
#       conspiracy theory       0.80      0.55      0.65        22
#            fake experts       0.83      0.71      0.77         7
#            false choice       0.22      0.29      0.25         7
#       false equivalence       0.22      0.25      0.24         8
# impossible expectations       0.94      0.71      0.81        21
#       misrepresentation       0.56      0.45      0.50        22
#      oversimplification       0.79      0.55      0.65        20
#            single cause       0.53      0.75      0.62        32
#      slothful induction       0.27      0.28      0.27        25
#
# ...
# ### ### ### ### ### ### ### ### ### ###
# Grid search microsoft/deberta-base, learning rate 1e-05
# Some weights of DebertaForSequenceClassification were not initialized from the model checkpoint at microsoft/deberta-base and are newly initialized: ['classifier.weight', 'pooler.dense.bias', 'classifier.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# You're using a DebertaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# 1 / 30: Train Loss:	2.3659	Val Loss:	2.0159	Accuracy:	0.3479	F1:	0.2233 *
# 2 / 30: Train Loss:	1.7853	Val Loss:	1.5334	Accuracy:	0.4967	F1:	0.3598 *
# 3 / 30: Train Loss:	1.3402	Val Loss:	1.3696	Accuracy:	0.5558	F1:	0.4308 *
# 4 / 30: Train Loss:	1.0260	Val Loss:	1.2266	Accuracy:	0.6061	F1:	0.4942 *
# 5 / 30: Train Loss:	0.7902	Val Loss:	1.1374	Accuracy:	0.6368	F1:	0.5711 *
# 6 / 30: Train Loss:	0.6133	Val Loss:	1.1232	Accuracy:	0.6565	F1:	0.6209 *
# 7 / 30: Train Loss:	0.4791	Val Loss:	1.1839	Accuracy:	0.6477	F1:	0.6259 *
# 8 / 30: Train Loss:	0.3811	Val Loss:	1.3164	Accuracy:	0.6368	F1:	0.6161
# 9 / 30: Train Loss:	0.2981	Val Loss:	1.2401	Accuracy:	0.6696	F1:	0.6561 *
# 10 / 30: Train Loss:	0.2376	Val Loss:	1.2508	Accuracy:	0.6718	F1:	0.6583 *
# 11 / 30: Train Loss:	0.1918	Val Loss:	1.2296	Accuracy:	0.6827	F1:	0.6846 *
# 12 / 30: Train Loss:	0.1465	Val Loss:	1.3557	Accuracy:	0.6521	F1:	0.6464
# 13 / 30: Train Loss:	0.1139	Val Loss:	1.3257	Accuracy:	0.6761	F1:	0.6716
# 14 / 30: Train Loss:	0.0882	Val Loss:	1.3271	Accuracy:	0.6740	F1:	0.6702
# No improvement for 3 epochs. Stopping early.
# best (higgest macro f1-score) val results:
#                          precision    recall  f1-score   support
#
#              ad hominem       0.70      0.69      0.69        67
#                anecdote       0.84      0.86      0.85        43
#          cherry picking       0.68      0.64      0.66        56
#       conspiracy theory       0.74      0.64      0.68        39
#            fake experts       0.77      0.83      0.80        12
#            false choice       0.75      0.69      0.72        13
#       false equivalence       0.50      0.71      0.59        14
# impossible expectations       0.63      0.59      0.61        37
#       misrepresentation       0.56      0.61      0.58        38
#      oversimplification       0.78      0.58      0.67        36
#            single cause       0.75      0.72      0.73        57
#      slothful induction       0.56      0.71      0.63        45
#
#                accuracy                           0.68       457
#               macro avg       0.69      0.69      0.68       457
#            weighted avg       0.69      0.68      0.68       457
#
# test results:
#                          precision    recall  f1-score   support
#
#              ad hominem       0.80      0.86      0.83        37
#                anecdote       0.85      0.92      0.88        24
#          cherry picking       0.85      0.55      0.67        31
#       conspiracy theory       0.94      0.73      0.82        22
#            fake experts       1.00      0.71      0.83         7
#            false choice       0.43      0.43      0.43         7
#       false equivalence       0.27      0.38      0.32         8
# impossible expectations       0.68      0.62      0.65        21
#       misrepresentation       0.53      0.82      0.64        22
#      oversimplification       0.75      0.75      0.75        20
#            single cause       0.73      0.69      0.71        32
#      slothful induction       0.44      0.48      0.46        25
#
#                accuracy                           0.70       256
#               macro avg       0.69      0.66      0.67       256
#            weighted avg       0.72      0.70      0.70       256
#
# ### ### ### ### ### ### ### ### ### ###
# {'test_acc': [0.65234375, 0.6328125, 0.03125, 0.02734375, 0.6015625, 0.5390625, 0.48828125, 0.5078125, 0.296875, 0.30078125, 0.6015625, 0.6015625, 0.70703125, 0.6953125], 'test_f1': [0.636725826724939, 0.6244407982110255, 0.005050505050505051, 0.004435994930291508, 0.5706471768971769, 0.5049375897147445, 0.4649922616760826, 0.5114821073167227, 0.21346652708534175, 0.21517849810532738, 0.5712763884274571, 0.5724528205844502, 0.687452352227602, 0.6658429648073112], 'eval_acc': [0.7024070021881839, 0.6849015317286652, 0.030634573304157548, 0.028446389496717725, 0.5820568927789934, 0.5557986870897156, 0.5098468271334792, 0.5207877461706784, 0.2888402625820569, 0.2800875273522976, 0.6061269146608315, 0.6192560175054704, 0.6936542669584245, 0.6827133479212254], 'eval_f1': [0.6719505775235829, 0.6612776420044664, 0.004953998584571833, 0.004609929078014185, 0.5774249734155712, 0.5337320762079748, 0.5082194559634832, 0.5236603978190266, 0.1962318403678687, 0.18768070103806286, 0.605651420019509, 0.6077226747490879, 0.6911624319408282, 0.6846392826633299], 'wd': [0.01, 0.1, 0.01, 0.1, 0.01, 0.1, 0.01, 0.1, 0.01, 0.1, 0.01, 0.1, 0.01, 0.1]}
# ### ### ### ### ### ### ### ### ### ###
# Grid search microsoft/deberta-v2-xlarge, learning rate 1e-05
# Some weights of DebertaV2ForSequenceClassification were not initialized from the model checkpoint at microsoft/deberta-v2-xlarge and are newly initialized: ['classifier.weight', 'pooler.dense.bias', 'classifier.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# You're using a DebertaV2TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# 1 / 30: Train Loss:	21.0389	Val Loss:	2.1833	Accuracy:	0.2932	F1:	0.2272 *
# 2 / 30: Train Loss:	11.5078	Val Loss:	1.3374	Accuracy:	0.5777	F1:	0.5519 *
# 3 / 30: Train Loss:	4.9419	Val Loss:	1.1115	Accuracy:	0.6543	F1:	0.6404 *
# 4 / 30: Train Loss:	2.4948	Val Loss:	0.9952	Accuracy:	0.6674	F1:	0.6597 *
# 5 / 30: Train Loss:	1.2027	Val Loss:	0.9343	Accuracy:	0.7155	F1:	0.7126 *
# 6 / 30: Train Loss:	0.6009	Val Loss:	0.8813	Accuracy:	0.7155	F1:	0.7099
# 7 / 30: Train Loss:	0.3988	Val Loss:	0.9104	Accuracy:	0.7068	F1:	0.7012
# 8 / 30: Train Loss:	0.2287	Val Loss:	0.8626	Accuracy:	0.7199	F1:	0.7183 *
# 9 / 30: Train Loss:	0.1779	Val Loss:	0.8560	Accuracy:	0.7177	F1:	0.7072
# 10 / 30: Train Loss:	0.0951	Val Loss:	0.8309	Accuracy:	0.7352	F1:	0.7256 *
# 11 / 30: Train Loss:	0.0695	Val Loss:	0.8607	Accuracy:	0.7330	F1:	0.7156
# 12 / 30: Train Loss:	0.0662	Val Loss:	0.8494	Accuracy:	0.7243	F1:	0.7170
# 13 / 30: Train Loss:	0.0421	Val Loss:	0.8227	Accuracy:	0.7330	F1:	0.7278 *
# 14 / 30: Train Loss:	0.0205	Val Loss:	0.8200	Accuracy:	0.7287	F1:	0.7284 *
# 15 / 30: Train Loss:	0.0238	Val Loss:	0.8322	Accuracy:	0.7309	F1:	0.7339 *
# 16 / 30: Train Loss:	0.0256	Val Loss:	0.8470	Accuracy:	0.7374	F1:	0.7215
# 17 / 30: Train Loss:	0.0473	Val Loss:	0.8698	Accuracy:	0.7199	F1:	0.7115
# 18 / 30: Train Loss:	0.0262	Val Loss:	0.8126	Accuracy:	0.7440	F1:	0.7335
# No improvement for 3 epochs. Stopping early.
# best (higgest macro f1-score) val results:
#                          precision    recall  f1-score   support
#
#              ad hominem       0.76      0.75      0.75        67
#                anecdote       0.95      0.86      0.90        43
#          cherry picking       0.69      0.66      0.67        56
#       conspiracy theory       0.78      0.82      0.80        39
#            fake experts       1.00      0.92      0.96        12
#            false choice       0.83      0.77      0.80        13
#       false equivalence       0.50      0.43      0.46        14
# impossible expectations       0.69      0.73      0.71        37
#       misrepresentation       0.63      0.63      0.63        38
#      oversimplification       0.88      0.58      0.70        36
#            single cause       0.81      0.74      0.77        57
#      slothful induction       0.54      0.82      0.65        45
#
#                accuracy                           0.73       457
#               macro avg       0.75      0.73      0.73       457
#            weighted avg       0.75      0.73      0.73       457
#
# test results:
#                          precision    recall  f1-score   support
#
#              ad hominem       0.81      0.78      0.79        37
#                anecdote       0.88      0.92      0.90        24
#          cherry picking       0.77      0.77      0.77        31
#       conspiracy theory       0.78      0.82      0.80        22
#            fake experts       1.00      1.00      1.00         7
#            false choice       0.62      0.71      0.67         7
#       false equivalence       0.50      0.38      0.43         8
# impossible expectations       0.69      0.86      0.77        21
#       misrepresentation       0.68      0.68      0.68        22
#      oversimplification       0.78      0.70      0.74        20
#            single cause       0.81      0.66      0.72        32
#      slothful induction       0.50      0.56      0.53        25
#
#                accuracy                           0.74       256
#               macro avg       0.74      0.74      0.73       256
#            weighted avg       0.75      0.74      0.74       256
#
# ### ### ### ### ### ### ### ### ### ###
# {'test_acc': [0.65234375, 0.6328125, 0.03125, 0.02734375, 0.6015625, 0.5390625, 0.48828125, 0.5078125, 0.296875, 0.30078125, 0.6015625, 0.6015625, 0.70703125, 0.6953125, 0.7421875], 'test_f1': [0.636725826724939, 0.6244407982110255, 0.005050505050505051, 0.004435994930291508, 0.5706471768971769, 0.5049375897147445, 0.4649922616760826, 0.5114821073167227, 0.21346652708534175, 0.21517849810532738, 0.5712763884274571, 0.5724528205844502, 0.687452352227602, 0.6658429648073112, 0.7332474105800544], 'eval_acc': [0.7024070021881839, 0.6849015317286652, 0.030634573304157548, 0.028446389496717725, 0.5820568927789934, 0.5557986870897156, 0.5098468271334792, 0.5207877461706784, 0.2888402625820569, 0.2800875273522976, 0.6061269146608315, 0.6192560175054704, 0.6936542669584245, 0.6827133479212254, 0.7308533916849015], 'eval_f1': [0.6719505775235829, 0.6612776420044664, 0.004953998584571833, 0.004609929078014185, 0.5774249734155712, 0.5337320762079748, 0.5082194559634832, 0.5236603978190266, 0.1962318403678687, 0.18768070103806286, 0.605651420019509, 0.6077226747490879, 0.6911624319408282, 0.6846392826633299, 0.7339147057537363], 'wd': [0.01, 0.1, 0.01, 0.1, 0.01, 0.1, 0.01, 0.1, 0.01, 0.1, 0.01, 0.1, 0.01, 0.1, 0.01]}
# ### ### ### ### ### ### ### ### ### ###
# Grid search microsoft/deberta-v2-xlarge, learning rate 1e-05
# Some weights of DebertaV2ForSequenceClassification were not initialized from the model checkpoint at microsoft/deberta-v2-xlarge and are newly initialized: ['classifier.weight', 'pooler.dense.bias', 'classifier.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# You're using a DebertaV2TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# 1 / 30: Train Loss:	20.8805	Val Loss:	2.0141	Accuracy:	0.3348	F1:	0.2547 *
# 2 / 30: Train Loss:	10.2292	Val Loss:	1.2911	Accuracy:	0.6193	F1:	0.5923 *
# 3 / 30: Train Loss:	4.2030	Val Loss:	1.1167	Accuracy:	0.6389	F1:	0.6179 *
# 4 / 30: Train Loss:	1.9775	Val Loss:	1.0339	Accuracy:	0.6499	F1:	0.6522 *
# 5 / 30: Train Loss:	1.1588	Val Loss:	0.9071	Accuracy:	0.7046	F1:	0.7013 *
# 6 / 30: Train Loss:	0.5947	Val Loss:	0.9418	Accuracy:	0.6980	F1:	0.6912
# 7 / 30: Train Loss:	0.6196	Val Loss:	0.9151	Accuracy:	0.7155	F1:	0.6972
# 8 / 30: Train Loss:	0.3262	Val Loss:	0.9448	Accuracy:	0.7002	F1:	0.6899
# No improvement for 3 epochs. Stopping early.
# best (higgest macro f1-score) val results:
#                          precision    recall  f1-score   support
#
#              ad hominem       0.74      0.69      0.71        67
#                anecdote       0.95      0.86      0.90        43
#          cherry picking       0.60      0.79      0.68        56
#       conspiracy theory       0.79      0.69      0.74        39
#            fake experts       0.69      0.92      0.79        12
#            false choice       0.91      0.77      0.83        13
#       false equivalence       0.71      0.36      0.48        14
# impossible expectations       0.65      0.65      0.65        37
#       misrepresentation       0.51      0.61      0.55        38
#      oversimplification       0.85      0.61      0.71        36
#            single cause       0.70      0.82      0.76        57
#      slothful induction       0.65      0.58      0.61        45
#
#                accuracy                           0.70       457
#               macro avg       0.73      0.69      0.70       457
#            weighted avg       0.72      0.70      0.70       457
#
# test results:
#                          precision    recall  f1-score   support
#
#              ad hominem       0.72      0.78      0.75        37
#                anecdote       0.92      0.92      0.92        24
#          cherry picking       0.64      0.68      0.66        31
#       conspiracy theory       0.74      0.64      0.68        22
#            fake experts       1.00      0.86      0.92         7
#            false choice       0.57      0.57      0.57         7
#       false equivalence       0.57      0.50      0.53         8
# impossible expectations       0.68      0.71      0.70        21
#       misrepresentation       0.57      0.73      0.64        22
#      oversimplification       0.70      0.80      0.74        20
#            single cause       0.83      0.75      0.79        32
#      slothful induction       0.67      0.48      0.56        25
#
#                accuracy                           0.71       256
#               macro avg       0.72      0.70      0.71       256
#            weighted avg       0.72      0.71      0.71       256
#
# ### ### ### ### ### ### ### ### ### ###
# {'test_acc': [0.65234375, 0.6328125, 0.03125, 0.02734375, 0.6015625, 0.5390625, 0.48828125, 0.5078125, 0.296875, 0.30078125, 0.6015625, 0.6015625, 0.70703125, 0.6953125, 0.7421875, 0.71484375], 'test_f1': [0.636725826724939, 0.6244407982110255, 0.005050505050505051, 0.004435994930291508, 0.5706471768971769, 0.5049375897147445, 0.4649922616760826, 0.5114821073167227, 0.21346652708534175, 0.21517849810532738, 0.5712763884274571, 0.5724528205844502, 0.687452352227602, 0.6658429648073112, 0.7332474105800544, 0.705317860243515], 'eval_acc': [0.7024070021881839, 0.6849015317286652, 0.030634573304157548, 0.028446389496717725, 0.5820568927789934, 0.5557986870897156, 0.5098468271334792, 0.5207877461706784, 0.2888402625820569, 0.2800875273522976, 0.6061269146608315, 0.6192560175054704, 0.6936542669584245, 0.6827133479212254, 0.7308533916849015, 0.7045951859956237], 'eval_f1': [0.6719505775235829, 0.6612776420044664, 0.004953998584571833, 0.004609929078014185, 0.5774249734155712, 0.5337320762079748, 0.5082194559634832, 0.5236603978190266, 0.1962318403678687, 0.18768070103806286, 0.605651420019509, 0.6077226747490879, 0.6911624319408282, 0.6846392826633299, 0.7339147057537363, 0.7012603451433045], 'wd': [0.01, 0.1, 0.01, 0.1, 0.01, 0.1, 0.01, 0.1, 0.01, 0.1, 0.01, 0.1, 0.01, 0.1, 0.01, 0.1]}
# ### ### ### ### ### ### ### ### ### ###

# %%
import pandas as pd

# %%
pd.DataFrame(results)
# Out:
#     test_acc   test_f1  eval_acc   eval_f1    wd
# 0   0.652344  0.636726  0.702407  0.671951  0.01
# 1   0.632812  0.624441  0.684902  0.661278  0.10
# 2   0.031250  0.005051  0.030635  0.004954  0.01
# 3   0.027344  0.004436  0.028446  0.004610  0.10
# 4   0.601562  0.570647  0.582057  0.577425  0.01
# 5   0.539062  0.504938  0.555799  0.533732  0.10
# 6   0.488281  0.464992  0.509847  0.508219  0.01
# 7   0.507812  0.511482  0.520788  0.523660  0.10
# 8   0.296875  0.213467  0.288840  0.196232  0.01
# 9   0.300781  0.215178  0.280088  0.187681  0.10
# 10  0.601562  0.571276  0.606127  0.605651  0.01
# 11  0.601562  0.572453  0.619256  0.607723  0.10
# 12  0.707031  0.687452  0.693654  0.691162  0.01
# 13  0.695312  0.665843  0.682713  0.684639  0.10
# 14  0.742188  0.733247  0.730853  0.733915  0.01
# 15  0.714844  0.705318  0.704595  0.701260  0.10
